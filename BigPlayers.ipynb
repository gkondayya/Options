# %% [markdown]
# <a href="https://colab.research.google.com/github/gkondayya/Options/blob/main/BigPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime

# %%
#url="https://raw.githubusercontent.com/gkondayya/Options/main/fao_participant_oi_25052022.csv"
url="https://www1.nseindia.com/content/nsccl/fao_participant_oi_27052022.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   Participant wise Open Interest (no. of contracts) in Equity Derivatives as on May 27  \
# 0                                        Client Type
# 1                                             Client
# 2                                                DII
# 3                                                FII
# 4                                                Pro
#
#               2022""          Unnamed: 2         Unnamed: 3  \
# 0  Future Index Long  Future Index Short  Future Stock Long
# 1             218045              192119            1367615
# 2              25558               62614              45591
# 3              71165               76212            1375838
# 4              41058               24881             259875
#
#              Unnamed: 4              Unnamed: 5             Unnamed: 6  \
# 0  Future Stock Short\t  Option Index Call Long  Option Index Put Long
# 1                196298                 1467875                1617614
# ...

# %%
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df.head()
# Out:
# 0 Client Type Future Index Long Future Index Short Future Stock Long  \
# 1      Client            218045             192119           1367615
# 2         DII             25558              62614             45591
# 3         FII             71165              76212           1375838
# 4         Pro             41058              24881            259875
# 5       TOTAL            355826             355826           3048919
#
# 0 Future Stock Short\t Option Index Call Long Option Index Put Long  \
# 1               196298                1467875               1617614
# 2              1683465                    839                 29102
# 3              1072421                 276592                404118
# 4                96735                 667983                703359
# 5              3048919                2413288               2754192
#
# 0 Option Index Call Short Option Index Put Short Option Stock Call Long  \
# ...

# %%
df.dropna(axis=1)
# Out:
# 0 Client Type Future Index Long Future Index Short Future Stock Long  \
# 1      Client            218045             192119           1367615
# 2         DII             25558              62614             45591
# 3         FII             71165              76212           1375838
# 4         Pro             41058              24881            259875
# 5       TOTAL            355826             355826           3048919
#
# 0 Future Stock Short\t Option Index Call Long Option Index Put Long  \
# 1               196298                1467875               1617614
# 2              1683465                    839                 29102
# 3              1072421                 276592                404118
# 4                96735                 667983                703359
# 5              3048919                2413288               2754192
#
# 0 Option Index Call Short Option Index Put Short Option Stock Call Long  \
# ...

# %%
df['Future Stock Short\t']
# Out:
# 1     196298
# 2    1683465
# 3    1072421
# 4      96735
# 5    3048919
# Name: Future Stock Short\t, dtype: object

# %%
todays_date = datetime.datetime.now().date()
index = pd.date_range(todays_date, periods=1, freq='D')
columns = ["Date","FII_Fut","DII_Fut","PRO_Fut","FII_Opt","DII_Opt","PRO_Opt","NET_SMART_Fut","NET_SMART_Opt"]

#todays_date="2022-05-26"

# Creating a data frame
data = {'Date': [todays_date],
        'FII_Fut': [0],
        'DII_Fut': [0],
        'PRO_Fut': [0],
        'FII_Opt': [0],
        'DII_Opt': [0],
        'PRO_Opt': [0],
        'NET_SMART_Fut': [0],
        'NET_SMART_Opt': [0],
       }
  
df2 = pd.DataFrame(data, columns =columns,index=None)



df2
# Out:
#          Date  FII_Fut  DII_Fut  PRO_Fut  FII_Opt  DII_Opt  PRO_Opt  \
# 0  2022-05-27        0        0        0        0        0        0
#
#    NET_SMART_Fut  NET_SMART_Opt
# 0              0              0

# %%
df['Future Index Long'] = df['Future Index Long'].astype(int)
df['Future Index Short'] = df['Future Index Short'].astype(int)
df["Fut_OI"]=df['Future Index Long']-df['Future Index Short']

df2['FII_Fut'][0]=df['Fut_OI'][2]
df2['DII_Fut'][0]=df['Fut_OI'][3]
df2['PRO_Fut'][0]=df['Fut_OI'][4]
#df2['NET_SMART_Fut'][0] = df2['FII_Fut'][0]+df2['DII_Fut'][0]+df2['PRO_Fut'][0]

df2['NET_SMART_Fut'].iloc[0] = df2['FII_Fut'].iloc[0]+df2['DII_Fut'].iloc[0]+df2['PRO_Fut'].iloc[0]


df['Option Index Call Long'] = df['Option Index Call Long'].astype(int)
df['Option Index Call Short'] = df['Option Index Call Short'].astype(int)
df["Option_CALL_OI"]=df['Option Index Call Long']-df['Option Index Call Short']

df['Option Index Put Long'] = df['Option Index Put Long'].astype(int)
df['Option Index Put Short'] = df['Option Index Put Short'].astype(int)
df["Option_Put_OI"]=df['Option Index Put Long']-df['Option Index Put Short']

df['Option_OI']=df["Option_CALL_OI"]-df["Option_Put_OI"]

df2['FII_Opt'][0]=df['Option_OI'][2]
df2['DII_Opt'][0]=df['Option_OI'][3]
df2['PRO_Opt'][0]=df['Option_OI'][4]
df2['NET_SMART_Opt'].iloc[0]= df2['FII_Opt'].iloc[0]+df2['DII_Opt'].iloc[0]+df2['PRO_Opt'].iloc[0]

df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# ...

# %%
df2
# Out:
#          Date  FII_Fut  DII_Fut  PRO_Fut  FII_Opt  DII_Opt  PRO_Opt  \
# 0  2022-05-27   -37056    -5047    16177   -28263   -62895    38658
#
#    NET_SMART_Fut  NET_SMART_Opt
# 0         -25926         -52500

# %%
#df2.to_csv('BigPlayers.csv',index=False)

# %%
# Saving CSV file at Google Drive
#from google.colab import drive

#drive.mount('/content/drive')
#path = '/content/drive/My Drive/BigPlayers.csv'

#with open(path, 'w', encoding = 'utf-8-sig') as f:
#  df2.to_csv(f)

# %%
from google.colab import files
import io
uploaded = files.upload()
df10 = pd.read_csv(io.BytesIO(uploaded['BigPlayers.csv']))
#df10 = df10.iloc[:-1 , :]
# Out:
#      <input type="file" id="files-6bc6d34f-ff9b-474c-b16f-119f311f2d72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bc6d34f-ff9b-474c-b16f-119f311f2d72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BigPlayers.csv to BigPlayers.csv

# %%
#df10 = df10.drop('Unnamed: 0', 1)
#df10 = df10.drop('Unnamed: 0.1', 1)
#df10

#df10=df10.drop(df10.filter(regex="Unname"),axis=1, inplace=True)
df10
# Out:
#           Date  FII_Fut  DII_Fut  PRO_Fut  FII_Opt  DII_Opt  PRO_Opt  \
# 0   2022-05-09   -46411  -100624    26421   -34144  -225801  -288325
# 1   2022-05-10   -38561   -96340    33192   -32237  -243138  -316793
# 2   2022-05-11   -36396  -108216    32668   -32249  -205428  -264741
# 3   2022-05-12   -21511  -124639    28486   -29745  -257349  -232734
# 4   2022-05-13   -17910   -88982    20260   -27523  -232496  -298962
# 5   2022-05-14   -19602   -77247     7592   -27523  -229931  -218642
# 6   2022-05-18   -25942   -63669      -63   -29291  -199406  -157138
# 7   2022-05-19   -19791   -75387     2148   -29377  -211247  -161433
# 8   2022-05-20   -27716   -38378     1038   -29756  -108810    66225
# 9   2022-05-23   -28522   -39105     4123   -26838  -127292  -134730
# 10  2022-05-24   -28859   -47342    11247   -31337   -73463  -155808
# 11  2022-05-25   -28572   -32907     7292   -33920  -136253  -259716
# 12  2022-05-26   -33560   -15410    19188   -28283   -79977   -33468
# ...

# %%
df10 = pd.concat([df10, df2], axis=0)
df10
# Out:
#           Date  FII_Fut  DII_Fut  PRO_Fut  FII_Opt  DII_Opt  PRO_Opt  \
# 0   2022-05-09   -46411  -100624    26421   -34144  -225801  -288325
# 1   2022-05-10   -38561   -96340    33192   -32237  -243138  -316793
# 2   2022-05-11   -36396  -108216    32668   -32249  -205428  -264741
# 3   2022-05-12   -21511  -124639    28486   -29745  -257349  -232734
# 4   2022-05-13   -17910   -88982    20260   -27523  -232496  -298962
# 5   2022-05-14   -19602   -77247     7592   -27523  -229931  -218642
# 6   2022-05-18   -25942   -63669      -63   -29291  -199406  -157138
# 7   2022-05-19   -19791   -75387     2148   -29377  -211247  -161433
# 8   2022-05-20   -27716   -38378     1038   -29756  -108810    66225
# 9   2022-05-23   -28522   -39105     4123   -26838  -127292  -134730
# 10  2022-05-24   -28859   -47342    11247   -31337   -73463  -155808
# 11  2022-05-25   -28572   -32907     7292   -33920  -136253  -259716
# 12  2022-05-26   -33560   -15410    19188   -28283   -79977   -33468
# ...

# %%
#df10 = df2.append(new_row, ignore_index=False)

df11 = df10
df11['Fut_Change'] = df11['NET_SMART_Fut']-df11['NET_SMART_Fut'].shift(1)
df11
# Out:
#           Date  FII_Fut  DII_Fut  PRO_Fut  FII_Opt  DII_Opt  PRO_Opt  \
# 0   2022-05-09   -46411  -100624    26421   -34144  -225801  -288325
# 1   2022-05-10   -38561   -96340    33192   -32237  -243138  -316793
# 2   2022-05-11   -36396  -108216    32668   -32249  -205428  -264741
# 3   2022-05-12   -21511  -124639    28486   -29745  -257349  -232734
# 4   2022-05-13   -17910   -88982    20260   -27523  -232496  -298962
# 5   2022-05-14   -19602   -77247     7592   -27523  -229931  -218642
# 6   2022-05-18   -25942   -63669      -63   -29291  -199406  -157138
# 7   2022-05-19   -19791   -75387     2148   -29377  -211247  -161433
# 8   2022-05-20   -27716   -38378     1038   -29756  -108810    66225
# 9   2022-05-23   -28522   -39105     4123   -26838  -127292  -134730
# 10  2022-05-24   -28859   -47342    11247   -31337   -73463  -155808
# 11  2022-05-25   -28572   -32907     7292   -33920  -136253  -259716
# 12  2022-05-26   -33560   -15410    19188   -28283   -79977   -33468
# ...

# %%
df11['Opt_Change'] = df11['NET_SMART_Opt']-df11['NET_SMART_Opt'].shift(1)
df11
# Out:
#           Date  FII_Fut  DII_Fut  PRO_Fut  FII_Opt  DII_Opt  PRO_Opt  \
# 0   2022-05-09   -46411  -100624    26421   -34144  -225801  -288325
# 1   2022-05-10   -38561   -96340    33192   -32237  -243138  -316793
# 2   2022-05-11   -36396  -108216    32668   -32249  -205428  -264741
# 3   2022-05-12   -21511  -124639    28486   -29745  -257349  -232734
# 4   2022-05-13   -17910   -88982    20260   -27523  -232496  -298962
# 5   2022-05-14   -19602   -77247     7592   -27523  -229931  -218642
# 6   2022-05-18   -25942   -63669      -63   -29291  -199406  -157138
# 7   2022-05-19   -19791   -75387     2148   -29377  -211247  -161433
# 8   2022-05-20   -27716   -38378     1038   -29756  -108810    66225
# 9   2022-05-23   -28522   -39105     4123   -26838  -127292  -134730
# 10  2022-05-24   -28859   -47342    11247   -31337   -73463  -155808
# 11  2022-05-25   -28572   -32907     7292   -33920  -136253  -259716
# 12  2022-05-26   -33560   -15410    19188   -28283   -79977   -33468
# ...

# %%
from nsepy import get_history
#from datetime import datetime, timedelta
import datetime as dt
NIFTY=get_history(symbol='NIFTY',start=dt.datetime(2022,5,10),end=dt.datetime.now(),index=True)
BANKNIFTY=get_history(symbol='BANKNIFTY',start=dt.datetime(2022,5,10),end=dt.datetime.now(),index=True)
# Out:
#                 Open      High       Low     Close     Volume      Turnover
# Date
# 2022-05-10  34181.20  34781.80  34176.80  34482.65  137963004  4.938300e+10
# 2022-05-11  34686.30  34793.20  34143.20  34693.15  179510699  5.311390e+10
# 2022-05-12  34289.10  34341.20  33297.65  33532.15  382113108  7.136840e+10
# 2022-05-13  33925.95  34002.20  33007.90  33121.35  272709547  8.347250e+10
# 2022-05-16  33256.00  33821.65  33001.75  33597.60  195136858  5.232060e+10
# 2022-05-17  33796.20  34366.05  33680.60  34301.90  161500305  5.248140e+10
# 2022-05-18  34448.20  34655.80  34134.70  34163.70  146780579  5.561350e+10
# 2022-05-19  33461.00  33633.95  33180.60  33315.65  150355852  5.416020e+10
# 2022-05-20  33765.15  34358.05  33658.05  34276.40  129371809  4.517560e+10
# 2022-05-23  34321.40  34819.95  34117.35  34247.60  155978859  5.319590e+10
# 2022-05-24  34223.20  34586.45  34115.80  34290.15  163680878  4.884470e+10
# ...

# %%
df11['NIFTY'] = NIFTY['Close'].to_numpy()
df11['BANKNIFTY'] = BANKNIFTY['Close'].to_numpy()

df11
# Out:
#           Date  FII_Fut  DII_Fut  PRO_Fut  FII_Opt  DII_Opt  PRO_Opt  \
# 0   2022-05-09   -46411  -100624    26421   -34144  -225801  -288325
# 1   2022-05-10   -38561   -96340    33192   -32237  -243138  -316793
# 2   2022-05-11   -36396  -108216    32668   -32249  -205428  -264741
# 3   2022-05-12   -21511  -124639    28486   -29745  -257349  -232734
# 4   2022-05-13   -17910   -88982    20260   -27523  -232496  -298962
# 5   2022-05-14   -19602   -77247     7592   -27523  -229931  -218642
# 6   2022-05-18   -25942   -63669      -63   -29291  -199406  -157138
# 7   2022-05-19   -19791   -75387     2148   -29377  -211247  -161433
# 8   2022-05-20   -27716   -38378     1038   -29756  -108810    66225
# 9   2022-05-23   -28522   -39105     4123   -26838  -127292  -134730
# 10  2022-05-24   -28859   -47342    11247   -31337   -73463  -155808
# 11  2022-05-25   -28572   -32907     7292   -33920  -136253  -259716
# 12  2022-05-26   -33560   -15410    19188   -28283   -79977   -33468
# ...

# %%
df10.to_csv('BigPlayers.csv',index=False)
from google.colab import files
files.download('BigPlayers.csv')

# %%
import matplotlib.pyplot as plt
ax = df11.plot.bar(x='Date', y='Opt_Change', rot=0)

# %%
import seaborn as sb


fig, axes = plt.subplots(2, 2, figsize=(25, 15), sharey=False)
fig.suptitle('Market Makers view: Short Term Market Trend ')

axes[0,0].set_xticklabels(
    labels=df11["Date"], rotation=30)

axes[0,1].set_xticklabels(
    labels=df11["Date"], rotation=30)
axes[1,0].set_xticklabels(
    labels=df11["Date"], rotation=30)

axes[1,1].set_xticklabels(
    labels=df11["Date"], rotation=30)


# Options
clrs = ['red' if (x < 0) else 'green' for x in df11['Opt_Change'] ]
sb.barplot(ax=axes[0,0], x=df11["Date"], y=df11['Opt_Change'],palette=clrs)
axes[0,0].set_title("Options OI by Market makers")

# Futures
#axes[1].set_ylim([df11['Fut_Change'].min(), df11['Fut_Change'].max()])

clrs = ['red' if (x < 0) else 'green' for x in df11['Fut_Change'] ]
sb.barplot(ax=axes[0,1], x=df11["Date"], y=df11['Fut_Change'],palette=clrs)
axes[0,1].set_title("Futures OI by Market makers")

sb.lineplot(ax=axes[1,0], x=df11["Date"], y=df11['NIFTY'],marker="o",linewidth=5)
axes[1,0].set_title("NIFY")

sb.lineplot(ax=axes[1,1], x=df11["Date"], y=df11['BANKNIFTY'],marker="o",linewidth=5)
#sb.histplot(ax=axes[1,1], x=df11["Date"], y=df11['BANKNIFTY'])


axes[1,1].set_title("BANKNIFTY")



#plt.figure(figsize=(14,10))
#sb.set(font_scale = 1.5)

#g=sb.barplot(x =df11["Date"], y = df11['Opt_Change'],palette=clrs)
#alues = np.array([2,5,3,6,4,7,1])   
#idx = np.array(list('abcdefg')) 

#sb.barplot(x=idx, y=values, palette=clrs) # color=clrs)


# Show the plot
plt.show()

# %%
pip install nsepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36084 sha256=c5ade611e64df625b1c4f6f8c8c9ddef32c482b42a2c0301bac11d674e7dc368
#   Stored in directory: /root/.cache/pip/wheels/32/ab/d9/78ceea14cdf6de83376082b3cb0c2999fd77f823e35c47b9ec
# Successfully built nsepy
# ...

# %%
from nsepy import get_history
#from datetime import datetime, timedelta
import datetime as dt
NIFTY=get_history(symbol='NIFTY',start=dt.datetime(2022,5,1),end=dt.datetime(2022,5,26),index=True)
NIFTY
# Out:
#                 Open      High       Low     Close     Volume      Turnover
# Date
# 2022-05-02  16924.45  17092.25  16917.25  17069.10  278155513  2.122264e+11
# 2022-05-04  17096.60  17132.85  16623.95  16677.60  310632799  2.740552e+11
# 2022-05-05  16854.75  16945.70  16651.85  16682.65  265793403  2.179291e+11
# 2022-05-06  16415.55  16484.20  16340.90  16411.25  300527719  2.547295e+11
# 2022-05-09  16227.70  16403.70  16142.10  16301.85  288402950  2.327474e+11
# 2022-05-10  16248.90  16404.55  16197.30  16240.05  283061200  2.268527e+11
# 2022-05-11  16270.05  16318.75  15992.60  16167.10  284294438  2.299438e+11
# 2022-05-12  16021.10  16041.95  15735.75  15808.00  314921678  2.535234e+11
# 2022-05-13  15977.00  16083.60  15740.85  15782.15  369135540  2.745412e+11
# 2022-05-16  15845.10  15977.95  15739.65  15842.30  217646558  1.785219e+11
# 2022-05-17  15912.60  16284.25  15900.80  16259.30  295687774  2.278299e+11
# ...
